# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt

participant = 99
file_path = "Data/P" + str(participant) + "/participant_" + str(participant)

# %%
baseline_data = pd.read_excel(file_path + '_baseline.xlsx', engine='openpyxl')
exposure_data = pd.read_excel(file_path + '_exposure.xlsx', engine='openpyxl')
post_data = pd.read_excel(file_path + '_post.xlsx', engine='openpyxl')

# %%
plt.figure()
plt.plot(post_data.error)
